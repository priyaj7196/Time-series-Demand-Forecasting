# %% [markdown]
# # Stacked LSTM regression

# %%
# Suppress warnings 
import warnings,os
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Suppress INFO and WARNING messages

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
import tensorflow as tf
tf.random.set_seed(0)
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import LSTM, Dense, Activation, Dropout
from tensorflow.keras.utils import plot_model
from tensorflow.keras import optimizers, backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
TRAIN_RANGE = (datetime.datetime(2015, 5, 27), datetime.datetime(2018, 5, 22))
VALID_RANGE = (datetime.datetime(2018, 5, 23), datetime.datetime(2019, 5, 22))
TEST_RANGE = (datetime.datetime(2019, 5, 23), datetime.datetime(2020, 5, 22))
TIMESTEPS = 12  # Input 12 months to predict next month

# %% [markdown]
# ## 1. Read in dataset

# %%
data = pd.read_csv('Timeseries Analysis/AAPL.csv')

# %%
import datetime

def str_to_datetime(s):
    # If already a datetime or date, return as-is
    if isinstance(s, (datetime.datetime, datetime.date)):
        return s
    
    # Otherwise, parse from string
    date_part = s.split(' ')[0]
    year, month, day = map(int, date_part.split('-'))
    return datetime.datetime(year=year, month=month, day=day)
data=data[['date','close']]
data.rename(columns={'close':'stock_price'},inplace=True)
data['date']=data['date'].apply(str_to_datetime)
data['date']
data.index = data.pop('date')  # Set datetime index
data.head()
# Out:
#             stock_price
# date
# 2015-05-27      132.045
# 2015-05-28      131.780
# 2015-05-29      130.280
# 2015-06-01      130.535
# 2015-06-02      129.960

# %%
data.plot(figsize=(14, 8), title='Daily Apple Stock Prices')
# Out:
# <Axes: title={'center': 'Daily Apple Stock Prices'}, xlabel='date'>

# %% [markdown]
# ## 2.1 Normalize dataset

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data['NormalizedStock_price'] = scaler.fit_transform(data['stock_price'].values.reshape(-1, 1)).flatten()
data[['NormalizedStock_price']].plot(figsize=(14, 8), title='Daily Normalized Apple Stock Prices')
# Out:
# <Axes: title={'center': 'Daily Normalized Apple Stock Prices'}, xlabel='date'>

# %% [markdown]
# ## 2.2 Preprocess dataset

# %%
def create_dataset(data, timesteps=TIMESTEPS):
    """Create input and output pairs for training lstm.
    Params:
        data (pandas.DataFrame): Normalized dataset
        timesteps (int, default: TIMESTEPS): Input time length 
    Returns:
        X (numpy.array): Input for lstm
        y (numpy.array): Output for lstm
        y_date (list): Datetime of output
        start_values (list): Start valeus of each input
    """
    X, y, y_date, start_values = [], [], [], []
    
    for i in range(len(data) - timesteps):
        Xt = data.iloc[i:i+timesteps].values
        yt = data.iloc[i+timesteps]
        yt_date = data.index[i+timesteps].to_pydatetime()
        
        # Subtract a start value from each values in the timestep.
        start_value = Xt[0]
        Xt = Xt - start_value
        yt = yt - start_value
        
        X.append(Xt)
        y.append(yt)
        y_date.append(yt_date)
        start_values.append(start_value)
        
    return np.array(X), np.array(y), y_date, start_values

# %%
def split_train_valid_test(X, y, y_date, train_range=TRAIN_RANGE, valid_range=VALID_RANGE, test_range=TEST_RANGE):
    """Split X and y into train, valid, and test periods.
    Params:
        X (numpy.array): Input for lstm
        y (numpy.array): Output for lstm
        y_date (list): Datetime of output
        train_range (tuple): Train period
        valid_range (tuple): Validation period
        test_range (tuple): Test period
    Returns:
        X_train (pandas.DataFrame)
        X_valid (pandas.DataFrame)
        X_test (pandas.DataFrame)
        y_train (pandas.DataFrame)
        y_valid (pandas.DataFrame)
        y_test (pandas.DataFrame)
        y_date_train (list)
        y_date_valid (list)
        y_date_test (list)
    """
    train_end_idx = y_date.index(train_range[1])
    valid_end_idx = y_date.index(valid_range[1])
    
    X_train = X[:train_end_idx+1, :]
    X_valid = X[train_end_idx+1:valid_end_idx+1, :]
    X_test = X[valid_end_idx+1:, :]
    
    y_train = y[:train_end_idx+1]
    y_valid = y[train_end_idx+1:valid_end_idx+1]
    y_test = y[valid_end_idx+1:]
    
    y_date_train = y_date[:train_end_idx+1]
    y_date_valid = y_date[train_end_idx+1:valid_end_idx+1]
    y_date_test = y_date[valid_end_idx+1:]
    
    return X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test

# %%
# Create input and output pairs for training lstm.
X, y, y_date, start_values = create_dataset(data[['NormalizedStock_price']])

# Split X and y into train, valid, and test periods.
X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test = split_train_valid_test(X, y, y_date)

# %%
print(X_train.shape, X_valid.shape, X_test.shape)
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (742, 12, 1) (251, 12, 1) (253, 12, 1)
# (742, 1) (251, 1) (253, 1)

# %% [markdown]
# ## 3. Create stacked LSTM regression model

# %%
def create_model(timesteps=TIMESTEPS):
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape=(timesteps, 1), name='lstm_1'))  # Input timesteps months with scalar value.
    model.add(LSTM(32, name='lstm_2'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizers.Adam(learning_rate=0.01), metrics=['mean_absolute_error'])
    return model

# %%
# Create model
model = create_model()
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 12, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 87,201 (340.63 KB)
#  Trainable params: 87,201 (340.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Callbacks of training.
es = EarlyStopping(monitor='val_mean_absolute_error', min_delta=0, patience=15, verbose=1, mode='auto')
fn = 'trained_model.keras'
mc = ModelCheckpoint(filepath=fn, save_best_only=True)
callbacks = [es, mc]

# %%
# Start training model.
fit = model.fit(
    X_train, y_train, 
    batch_size=32,
    epochs=1000, 
    verbose=2,
    validation_data=(X_valid, y_valid), 
    callbacks=callbacks)
# Out:
# Epoch 1/1000
# 24/24 - 6s - 230ms/step - loss: 0.0020 - mean_absolute_error: 0.0297 - val_loss: 0.0012 - val_mean_absolute_error: 0.0252
# Epoch 2/1000
# 24/24 - 1s - 23ms/step - loss: 2.6551e-04 - mean_absolute_error: 0.0122 - val_loss: 5.0135e-04 - val_mean_absolute_error: 0.0164
# Epoch 3/1000
# 24/24 - 0s - 19ms/step - loss: 2.1670e-04 - mean_absolute_error: 0.0114 - val_loss: 3.8399e-04 - val_mean_absolute_error: 0.0143
# Epoch 4/1000
# 24/24 - 0s - 19ms/step - loss: 1.2147e-04 - mean_absolute_error: 0.0081 - val_loss: 3.2820e-04 - val_mean_absolute_error: 0.0134
# Epoch 5/1000
# 24/24 - 0s - 19ms/step - loss: 1.1204e-04 - mean_absolute_error: 0.0078 - val_loss: 3.0507e-04 - val_mean_absolute_error: 0.0129
# Epoch 6/1000
# 24/24 - 0s - 19ms/step - loss: 1.0047e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8379e-04 - val_mean_absolute_error: 0.0124
# Epoch 7/1000
# 24/24 - 0s - 20ms/step - loss: 9.2064e-05 - mean_absolute_error: 0.0069 - val_loss: 2.6918e-04 - val_mean_absolute_error: 0.0119
# Epoch 8/1000
# 24/24 - 1s - 22ms/step - loss: 8.5827e-05 - mean_absolute_error: 0.0066 - val_loss: 2.5830e-04 - val_mean_absolute_error: 0.0115
# Epoch 9/1000
# 24/24 - 1s - 21ms/step - loss: 8.1412e-05 - mean_absolute_error: 0.0064 - val_loss: 2.5064e-04 - val_mean_absolute_error: 0.0113
# Epoch 10/1000
# 24/24 - 0s - 19ms/step - loss: 7.8525e-05 - mean_absolute_error: 0.0063 - val_loss: 2.4523e-04 - val_mean_absolute_error: 0.0112
# Epoch 11/1000
# 24/24 - 0s - 20ms/step - loss: 7.6677e-05 - mean_absolute_error: 0.0062 - val_loss: 2.4130e-04 - val_mean_absolute_error: 0.0110
# Epoch 12/1000
# 24/24 - 1s - 24ms/step - loss: 7.5451e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3833e-04 - val_mean_absolute_error: 0.0109
# Epoch 13/1000
# 24/24 - 1s - 21ms/step - loss: 7.4616e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3613e-04 - val_mean_absolute_error: 0.0108
# Epoch 14/1000
# 24/24 - 0s - 19ms/step - loss: 7.4040e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3458e-04 - val_mean_absolute_error: 0.0108
# Epoch 15/1000
# 24/24 - 0s - 20ms/step - loss: 7.3659e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3355e-04 - val_mean_absolute_error: 0.0108
# Epoch 16/1000
# 24/24 - 1s - 21ms/step - loss: 7.3443e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3290e-04 - val_mean_absolute_error: 0.0107
# Epoch 17/1000
# 24/24 - 0s - 20ms/step - loss: 7.3361e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3254e-04 - val_mean_absolute_error: 0.0107
# Epoch 18/1000
# 24/24 - 1s - 26ms/step - loss: 7.3375e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3236e-04 - val_mean_absolute_error: 0.0107
# Epoch 19/1000
# 24/24 - 0s - 19ms/step - loss: 7.3452e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3230e-04 - val_mean_absolute_error: 0.0107
# Epoch 20/1000
# 24/24 - 1s - 21ms/step - loss: 7.3566e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3230e-04 - val_mean_absolute_error: 0.0107
# Epoch 21/1000
# 24/24 - 1s - 25ms/step - loss: 7.3702e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3233e-04 - val_mean_absolute_error: 0.0107
# Epoch 22/1000
# 24/24 - 1s - 36ms/step - loss: 7.3847e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3238e-04 - val_mean_absolute_error: 0.0107
# Epoch 23/1000
# 24/24 - 1s - 30ms/step - loss: 7.3995e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3242e-04 - val_mean_absolute_error: 0.0107
# Epoch 24/1000
# 24/24 - 1s - 24ms/step - loss: 7.4139e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3245e-04 - val_mean_absolute_error: 0.0107
# Epoch 25/1000
# 24/24 - 0s - 17ms/step - loss: 7.4275e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3248e-04 - val_mean_absolute_error: 0.0107
# Epoch 26/1000
# 24/24 - 1s - 21ms/step - loss: 7.4400e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3249e-04 - val_mean_absolute_error: 0.0107
# Epoch 27/1000
# 24/24 - 1s - 21ms/step - loss: 7.4510e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3249e-04 - val_mean_absolute_error: 0.0107
# Epoch 28/1000
# 24/24 - 1s - 29ms/step - loss: 7.4605e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3248e-04 - val_mean_absolute_error: 0.0107
# Epoch 29/1000
# 24/24 - 1s - 23ms/step - loss: 7.4683e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3247e-04 - val_mean_absolute_error: 0.0107
# Epoch 30/1000
# 24/24 - 1s - 30ms/step - loss: 7.4744e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3244e-04 - val_mean_absolute_error: 0.0107
# Epoch 31/1000
# 24/24 - 1s - 23ms/step - loss: 7.4788e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3242e-04 - val_mean_absolute_error: 0.0107
# Epoch 32/1000
# 24/24 - 0s - 20ms/step - loss: 7.4817e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3238e-04 - val_mean_absolute_error: 0.0107
# Epoch 33/1000
# 24/24 - 0s - 19ms/step - loss: 7.4830e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3235e-04 - val_mean_absolute_error: 0.0107
# Epoch 34/1000
# 24/24 - 0s - 18ms/step - loss: 7.4830e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3231e-04 - val_mean_absolute_error: 0.0106
# Epoch 35/1000
# 24/24 - 0s - 18ms/step - loss: 7.4817e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3228e-04 - val_mean_absolute_error: 0.0106
# Epoch 36/1000
# 24/24 - 1s - 28ms/step - loss: 7.4794e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3224e-04 - val_mean_absolute_error: 0.0106
# Epoch 37/1000
# 24/24 - 1s - 21ms/step - loss: 7.4760e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3220e-04 - val_mean_absolute_error: 0.0106
# Epoch 38/1000
# 24/24 - 1s - 21ms/step - loss: 7.4718e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3217e-04 - val_mean_absolute_error: 0.0106
# Epoch 39/1000
# 24/24 - 1s - 21ms/step - loss: 7.4669e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3213e-04 - val_mean_absolute_error: 0.0106
# Epoch 40/1000
# 24/24 - 0s - 20ms/step - loss: 7.4614e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3210e-04 - val_mean_absolute_error: 0.0106
# Epoch 41/1000
# 24/24 - 0s - 20ms/step - loss: 7.4555e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3206e-04 - val_mean_absolute_error: 0.0106
# Epoch 42/1000
# 24/24 - 0s - 19ms/step - loss: 7.4491e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3203e-04 - val_mean_absolute_error: 0.0106
# Epoch 43/1000
# 24/24 - 1s - 23ms/step - loss: 7.4424e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3200e-04 - val_mean_absolute_error: 0.0106
# Epoch 44/1000
# 24/24 - 1s - 26ms/step - loss: 7.4355e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3198e-04 - val_mean_absolute_error: 0.0106
# Epoch 45/1000
# 24/24 - 1s - 21ms/step - loss: 7.4284e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3195e-04 - val_mean_absolute_error: 0.0106
# Epoch 46/1000
# 24/24 - 1s - 30ms/step - loss: 7.4212e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3193e-04 - val_mean_absolute_error: 0.0106
# Epoch 47/1000
# 24/24 - 1s - 31ms/step - loss: 7.4140e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3191e-04 - val_mean_absolute_error: 0.0106
# Epoch 48/1000
# 24/24 - 0s - 21ms/step - loss: 7.4067e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3189e-04 - val_mean_absolute_error: 0.0106
# Epoch 49/1000
# 24/24 - 1s - 26ms/step - loss: 7.3995e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3187e-04 - val_mean_absolute_error: 0.0106
# Epoch 50/1000
# 24/24 - 1s - 30ms/step - loss: 7.3923e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3186e-04 - val_mean_absolute_error: 0.0106
# Epoch 51/1000
# 24/24 - 1s - 21ms/step - loss: 7.3852e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3185e-04 - val_mean_absolute_error: 0.0106
# Epoch 52/1000
# 24/24 - 0s - 18ms/step - loss: 7.3782e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3184e-04 - val_mean_absolute_error: 0.0106
# Epoch 53/1000
# 24/24 - 1s - 25ms/step - loss: 7.3713e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3183e-04 - val_mean_absolute_error: 0.0106
# Epoch 54/1000
# 24/24 - 0s - 19ms/step - loss: 7.3646e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3183e-04 - val_mean_absolute_error: 0.0106
# Epoch 55/1000
# 24/24 - 1s - 27ms/step - loss: 7.3579e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3183e-04 - val_mean_absolute_error: 0.0106
# Epoch 56/1000
# 24/24 - 0s - 17ms/step - loss: 7.3514e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3183e-04 - val_mean_absolute_error: 0.0106
# Epoch 57/1000
# 24/24 - 0s - 17ms/step - loss: 7.3451e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3183e-04 - val_mean_absolute_error: 0.0106
# Epoch 58/1000
# 24/24 - 1s - 23ms/step - loss: 7.3389e-05 - mean_absolute_error: 0.0063 - val_loss: 2.3184e-04 - val_mean_absolute_error: 0.0106
# Epoch 59/1000
# 24/24 - 1s - 27ms/step - loss: 7.3329e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3185e-04 - val_mean_absolute_error: 0.0106
# Epoch 60/1000
# 24/24 - 1s - 27ms/step - loss: 7.3270e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3186e-04 - val_mean_absolute_error: 0.0106
# Epoch 61/1000
# 24/24 - 1s - 24ms/step - loss: 7.3213e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3187e-04 - val_mean_absolute_error: 0.0106
# Epoch 62/1000
# 24/24 - 1s - 26ms/step - loss: 7.3157e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3189e-04 - val_mean_absolute_error: 0.0106
# Epoch 63/1000
# 24/24 - 1s - 25ms/step - loss: 7.3103e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3191e-04 - val_mean_absolute_error: 0.0106
# Epoch 64/1000
# 24/24 - 1s - 25ms/step - loss: 7.3050e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3193e-04 - val_mean_absolute_error: 0.0106
# Epoch 65/1000
# 24/24 - 0s - 17ms/step - loss: 7.2999e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3195e-04 - val_mean_absolute_error: 0.0106
# Epoch 66/1000
# 24/24 - 0s - 17ms/step - loss: 7.2949e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3198e-04 - val_mean_absolute_error: 0.0106
# Epoch 67/1000
# 24/24 - 1s - 26ms/step - loss: 7.2901e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3200e-04 - val_mean_absolute_error: 0.0106
# Epoch 68/1000
# 24/24 - 0s - 19ms/step - loss: 7.2854e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3203e-04 - val_mean_absolute_error: 0.0106
# Epoch 69/1000
# 24/24 - 0s - 18ms/step - loss: 7.2808e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3207e-04 - val_mean_absolute_error: 0.0106
# Epoch 70/1000
# 24/24 - 1s - 23ms/step - loss: 7.2764e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3210e-04 - val_mean_absolute_error: 0.0106
# Epoch 71/1000
# 24/24 - 0s - 19ms/step - loss: 7.2721e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3214e-04 - val_mean_absolute_error: 0.0106
# Epoch 72/1000
# 24/24 - 0s - 18ms/step - loss: 7.2679e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3218e-04 - val_mean_absolute_error: 0.0106
# Epoch 73/1000
# 24/24 - 0s - 20ms/step - loss: 7.2638e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3222e-04 - val_mean_absolute_error: 0.0106
# Epoch 74/1000
# 24/24 - 0s - 20ms/step - loss: 7.2598e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3226e-04 - val_mean_absolute_error: 0.0106
# Epoch 75/1000
# 24/24 - 0s - 19ms/step - loss: 7.2559e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3231e-04 - val_mean_absolute_error: 0.0106
# Epoch 76/1000
# 24/24 - 1s - 24ms/step - loss: 7.2522e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3236e-04 - val_mean_absolute_error: 0.0106
# Epoch 77/1000
# 24/24 - 1s - 26ms/step - loss: 7.2485e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3241e-04 - val_mean_absolute_error: 0.0106
# Epoch 78/1000
# 24/24 - 1s - 21ms/step - loss: 7.2449e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3247e-04 - val_mean_absolute_error: 0.0106
# Epoch 78: early stopping

# %%
# Plot training history
fig, (axL, axR) = plt.subplots(ncols=2, figsize=(10, 4))
axL.plot(fit.history['loss'], label="loss (mse) for training")
axL.plot(fit.history['val_loss'], label="loss (mse) for validation")
axL.set_title('model loss')
axL.set_xlabel('epoch')
axL.set_ylabel('loss')
axL.legend(loc='upper right')

axR.plot(fit.history['mean_absolute_error'], label="mae for training")
axR.plot(fit.history['val_mean_absolute_error'], label="mae for validation")
axR.set_title('model mse')
axR.set_xlabel('epoch')
axR.set_ylabel('mse')
axR.legend(loc='upper right')

plt.show()

# Load best model
model = load_model(fn)

# %%
def evaluate_model(data, scaler, X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test, start_values, model):
    """Evaluate trained model by rmse (root mean squared error) and mae (mean absolute error)'"""
    
    # Predict next month passengers
    pred_train = model.predict(X_train)
    pred_valid = model.predict(X_valid)
    pred_test = model.predict(X_test)
    
    # Add start_values that were subtracted when preprocessing.
    pred_train  = pred_train + start_values[:len(X_train)]
    pred_valid  = pred_valid + start_values[len(X_train):len(X_train)+len(X_valid)]
    pred_test  = pred_test + start_values[len(X_train)+len(X_valid):]
    
    # Inverse transform normalization
    pred_train = scaler.inverse_transform(pred_train).flatten()
    pred_valid = scaler.inverse_transform(pred_valid).flatten()
    pred_test = scaler.inverse_transform(pred_test).flatten()
    
    pred_df = data.copy()
    pred_df.loc[y_date_train[0]:y_date_train[-1], 'PredictionTrain'] = pred_train
    pred_df.loc[y_date_valid[0]:y_date_valid[-1], 'PredictionValid'] = pred_valid
    pred_df.loc[y_date_test[0]:y_date_test[-1], 'PredictionTest'] = pred_test
    pred_df[['stock_price', 'PredictionTrain', 'PredictionValid', 'PredictionTest']].plot(figsize=(12, 6), title='Predicted Apple Stock Prices')
    fig.show()
    
    # Add start_values that were subtracted when preprocessing.
    y_train  = y_train + start_values[:len(X_train)]
    y_valid  = y_valid + start_values[len(X_train):len(X_train)+len(X_valid)]
    y_test  = y_test + start_values[len(X_train)+len(X_valid):]
    
    # Inverse transform normalization
    y_train = scaler.inverse_transform(y_train).flatten()
    y_valid = scaler.inverse_transform(y_valid).flatten()
    y_test = scaler.inverse_transform(y_test).flatten()
    
    # Evaluate prediction scores of model.
    for y, pred, mode in zip([y_train, y_valid, y_test], [pred_train, pred_valid, pred_test], ['train', 'valid', 'test']):
        rmse = np.sqrt(mean_squared_error(y, pred))
        mae = mean_absolute_error(y, pred)
        print(f'{mode} rmse: {rmse:.06f}, mae: {mae:.06f}')

# %%
evaluate_model(data, scaler, X_train, X_valid, X_test, y_train, y_valid, y_test, y_date_train, y_date_valid, y_date_test, start_values, model)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# train rmse: 1.910920, mae: 1.344780
# valid rmse: 3.606402, mae: 2.512054
# test rmse: 6.480187, mae: 4.313686
